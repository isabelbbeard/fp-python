# %%
import pandas as pd
import numpy as np

from math import pi
import time

# %%
df = pd.read_csv('data/VizResults.csv')
df_key = pd.read_csv('data/VizResults_key.csv')
df.head()
# Out:
#                 Q1_1            Q1_2            Q7_1            Q7_2  \
# 0              Agree  Somewhat agree  Strongly agree  Strongly agree
# 1  Somewhat disagree        Disagree  Somewhat agree           Agree
# 2     Somewhat agree           Agree  Somewhat agree           Agree
# 3              Agree  Strongly agree  Strongly agree           Agree
# 4     Somewhat agree           Agree  Somewhat agree  Somewhat agree
#
#              Q7_3                                                Q11  \
# 0  Strongly agree  Confused about the user rating. '-' sign is co...
# 1           Agree  The dashed line makes it look like a minus. Th...
# 2           Agree  The pink circle is confusing - not sure what i...
# 3  Strongly agree  User rating looks like a minus sign. Maybe mov...
# 4  Somewhat agree  The price is confusing - didn't understand tha...
#
#                                                   Q9  \
# 0  Potential for 'active ingredients' but maybe n...
# ...

# %%
Q = 'Q102'
df[Q].value_counts()
# Out:
# Version 02    3
# Version 03    3
# Version 01    1
# Name: Q102, dtype: int64

# %%
df['Q46']
# Out:
# 0    The triangle with the price points - know righ...
# 1    The segment out of the radial is confusing - n...
# 2    Confused what the wedge/break and triangle mea...
# 3    The wedge on the left is confusing. Might make...
# 4    Lot of information to take in - takes a while ...
# 5    Took a while to understand the viz - the line ...
# 6    Confusing to establish what the middle circle ...
# Name: Q46, dtype: object
